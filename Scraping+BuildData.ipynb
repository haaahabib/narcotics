# %% [markdown]
# # Import Library

# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import zipfile

# %% [markdown]
# # Membuat Folder

# %%
# Fungsi untuk membuat folder jika belum ada
def create_path(destination):
    if not os.path.exists(destination):
        os.mkdir(destination)
    print(f"Output disimpan di {destination}")
    return destination

# %% [markdown]
# Fungsi `create_path` memastikan bahwa folder tempat penyimpanan file PDF sudah ada. Jika folder tidak ada, maka akan dibuat. Fungsi ini akan mengembalikan path folder tersebut.

# %% [markdown]
# # Mengekstrak Barang Bukti

# %%
import re

def extract_barang_bukti(text):
    # Periksa apakah input berupa string
    if isinstance(text, str):
        # Memperbaiki regex untuk menangkap berbagai bentuk pengenalan barang bukti
        match = re.search(r'(?i)(Menetapkan barang bukti|Menyatakan barang bukti|Barang bukti berupa|yang diajukan ke persidangan ini(?: berupa)?)\s*[:：]?\s*(.*?)(?=\s*(?:Dirampas|Membebankan|Menyatakan|[;])|$|\n\d+\.\s|$)', text, re.DOTALL | re.IGNORECASE)
        if match:
            barang_bukti = match.group(2).strip()
            # Membersihkan kata "berupa" jika ada
            barang_bukti = re.sub(r'berupa\s*[:：]?\s*', '', barang_bukti)
            return barang_bukti.strip()
    return None

# %% [markdown]
# Fungsi `extract_barang_bukti` menggunakan ekspresi reguler untuk mengekstrak bagian dari teks yang berisi informasi mengenai 'Barang Bukti'. Ini mencari kata kunci "Barang Bukti" dan mengambil teks setelahnya.

# %% [markdown]
# # Mengambil Data Detail Putusan

# %%
# Fungsi untuk mengambil konten dari halaman detail putusan
def get_detail_data(detail_url, pdf_dir):
    detail_response = requests.get(detail_url)
    detail_soup = BeautifulSoup(detail_response.content, 'html.parser')

    # Mengambil tabel dengan class 'table'
    table = detail_soup.find('table', class_='table')

    if not table:
        print(f"Tabel tidak ditemukan di {detail_url}")
        return None

    # Mengambil semua <tr> di dalam tabel
    rows = table.find_all('tr')

    # Dictionary untuk menyimpan data putusan
    data = {
        'Nomor': None,
        'Lembaga Peradilan': None,
        'Catatan Amar': None,
        'File Path': None,  # Untuk menyimpan lokasi file PDF yang diunduh
        'Barang Bukti': None
    }

    for row in rows:
        # Mengambil semua <td> dalam <tr>
        td_elements = row.find_all('td')

        if len(td_elements) >= 2:  # Pastikan ada setidaknya dua elemen <td>
            header_text = td_elements[0].get_text(strip=True)  # Ambil teks dari <td> pertama
            value_text = td_elements[1].get_text(strip=True)   # Ambil teks dari <td> kedua

            # Menyimpan data ke dictionary sesuai dengan nama kolom
            if 'Nomor' in header_text:
                data['Nomor'] = value_text
            elif 'Lembaga Peradilan' in header_text:
                data['Lembaga Peradilan'] = value_text
            elif 'Catatan Amar' in header_text:
                data['Catatan Amar'] = value_text

    # Mengecek apakah nomor mengandung tahun 2022, 2023, atau 2024
    if data['Nomor'] and not re.search(r'\b(2022|2023|2024)\b', data['Nomor']):
        return None  # Abaikan jika tahun tidak sesuai

    # Ekstrak 'Barang Bukti' dari 'Catatan Amar' dengan cara lebih fleksibel
    data['Barang Bukti'] = extract_barang_bukti(data['Catatan Amar'])

    # Mencoba mengunduh PDF
    pdf_link = detail_soup.find('a', href=True, string=lambda x: x and x.endswith('.pdf'))
    if pdf_link:
        pdf_url = pdf_link['href']
        pdf_url = requests.compat.urljoin(detail_url, pdf_url)  # Buat URL PDF lengkap jika perlu
        safe_filename = re.sub(r'[\/:*?"<>|]', '_', data['Nomor'])  # Mengganti karakter yang tidak aman pada nama file
        pdf_path = os.path.join(pdf_dir, f"{safe_filename}.pdf")
        pdf_response = requests.get(pdf_url)

        if pdf_response.status_code == 200:
            # Menyimpan file PDF hanya jika pengunduhan berhasil
            with open(pdf_path, 'wb') as pdf_file:
                pdf_file.write(pdf_response.content)

            print(f"PDF berhasil diunduh: {pdf_path}")
            # Menyimpan path file PDF ke dalam data
            data['File Path'] = pdf_path
        else:
            print(f"Gagal mengunduh PDF dari {pdf_url} dengan status {pdf_response.status_code}")
            return None  # Batalkan pengambilan data jika PDF gagal diunduh
    else:
        print(f"Tidak ada link PDF ditemukan di {detail_url}")
        return None  # Batalkan pengambilan data jika tidak ada link PDF

    return data  # Hanya kembalikan data jika PDF berhasil diunduh

# %% [markdown]
# Fungsi `get_detail_data` digunakan untuk mengambil data dari halaman detail putusan. Ini mencakup ekstraksi informasi dari tabel HTML dan mencoba mengunduh file PDF terkait. Jika berhasil mengunduh PDF, path file disimpan dalam dictionary yang berisi informasi putusan.

# %% [markdown]
# # Mengemas PDF Menjadi ZIP

# %%
# Fungsi untuk mengemas folder PDF menjadi file ZIP
def create_zip_from_folder(folder_path, output_zip):
    with zipfile.ZipFile(output_zip, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))
    print(f"File ZIP berhasil dibuat: {output_zip}")

# %% [markdown]
# Fungsi `create_zip_from_folder` akan membuat file ZIP dari semua file dalam folder yang diberikan. Ini akan digunakan untuk mengemas file PDF yang diunduh ke dalam satu file ZIP.

# %% [markdown]
# # Mengambil dan Memproses Data dari Halaman Web

# %%
# URL halaman direktori utama
base_url = 'https://putusan3.mahkamahagung.go.id/direktori/index/pengadilan/pn-rantau-prapat/kategori/narkotika-dan-psikotropika-1/tahunjenis/putus/tahun/2024.html'
pdf_folder = create_path('putusan')  # Membuat folder untuk menyimpan file PDF

total_data = 0
putusan_list = []  # List untuk menyimpan data putusan
page_number = 1

# Variabel untuk menghitung statistik
total_halaman = 0
berhasil_diekraksi = 0
berhasil_pdf = 0
gagal_diekraksi = 0
gagal_pdf = 0

# Fungsi untuk memperbarui statistik
def update_statistics(detail_data, pdf_data):
    global total_halaman, berhasil_diekraksi, berhasil_pdf, gagal_diekraksi, gagal_pdf

    total_halaman += 1

    if detail_data:
        berhasil_diekraksi += 1  # Jika data berhasil diekstraksi
    else:
        gagal_diekraksi += 1  # Jika data gagal diekstraksi atau tidak sesuai

    if pdf_data:
        berhasil_pdf += 1  # Jika PDF berhasil diunduh
    else:
        gagal_pdf += 1  # Jika PDF gagal diunduh

# Looping untuk mengambil data dari halaman hingga mencapai 100 data
while total_data < 50:
    # Memperbarui URL untuk pagination
    if page_number > 1:
        page_url = f"https://putusan3.mahkamahagung.go.id/direktori/index/pengadilan/pn-rantau-prapat/kategori/narkotika-dan-psikotropika-1/tahunjenis/putus/tahun/2024/page/{page_number}"
    else:
        page_url = base_url  # Halaman pertama tetap URL dasar

    print(f"Mengambil data dari: {page_url}")

    # Mengirim request ke halaman direktori
    response = requests.get(page_url)

    # Cek apakah permintaan berhasil
    if response.status_code == 200:
        # Parsing konten HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Mencari semua tag <strong> di halaman
        strong_tags = soup.find_all('strong')

        # Mengambil link detail dari setiap strong tag
        for strong in strong_tags:
            link_tag = strong.find('a', href=True)  # Mencari link dalam <strong>
            if link_tag:
                detail_url = link_tag['href']  # Mendapatkan URL detail
                print(f"Mengambil data dari: {detail_url}")
                detail_data = get_detail_data(detail_url, pdf_folder)  # Ambil data dari halaman detail

                # Hanya memperbarui statistik jika detail_data tidak None
                if detail_data:
                    update_statistics(detail_data, detail_data.get('File Path') is not None)

                    if detail_data['Nomor'] not in [d['Nomor'] for d in putusan_list]:
                        putusan_list.append(detail_data)  # Simpan data ke list
                        total_data += 1  # Increment total data yang berhasil diambil

                # Hentikan jika sudah mencapai 100 data
                if total_data >= 100:
                    break
    else:
        print("Gagal mengakses halaman.")
        break  # Keluar dari loop jika gagal mengakses halaman

    page_number += 1  # Naik ke halaman berikutnya

# Menampilkan statistik setelah proses selesai
print(f"\nTotal halaman yang diproses: {total_halaman}")
print(f"Berhasil diekstraksi: {berhasil_diekraksi} ({(berhasil_diekraksi / total_halaman) * 100:.2f}%)")
print(f"Berhasil mengunduh PDF: {berhasil_pdf} ({(berhasil_pdf / total_halaman) * 100:.2f}%)")
print(f"Gagal diekstraksi atau tidak sesuai: {gagal_diekraksi} ({(gagal_diekraksi / total_halaman) * 100:.2f}%)")
print(f"Gagal mengunduh PDF: {gagal_pdf} ({(gagal_pdf / total_halaman) * 100:.2f}%)")
print("Proses crawling selesai.")
# Out:
# Output disimpan di putusan
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/index/pengadilan/pn-rantau-prapat/kategori/narkotika-dan-psikotropika-1/tahunjenis/putus/tahun/2024.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefc18c5d4a9f42bba3303731363437.html
# PDF berhasil diunduh: putusan/932_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefc18c41577c428060303731363030.html
# PDF berhasil diunduh: putusan/943_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefc119e6a00b88b5af313733373235.html
# PDF berhasil diunduh: putusan/946_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc852b161a128d3c323134323431.html
# Tidak ada link PDF ditemukan di https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc852b161a128d3c323134323431.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc8524afcbbe8d27323134323330.html
# Tidak ada link PDF ditemukan di https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc8524afcbbe8d27323134323330.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84fc0b11d2a842323134313232.html
# PDF berhasil diunduh: putusan/837_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84ef5b30fc963c323134313030.html
# PDF berhasil diunduh: putusan/953_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84e48e1ab8be38323134303432.html
# PDF berhasil diunduh: putusan/951_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84d7904dccb32f323134303231.html
# Tidak ada link PDF ditemukan di https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84d7904dccb32f323134303231.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84d31ccb1c90bf323134303133.html
# Tidak ada link PDF ditemukan di https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc84d31ccb1c90bf323134303133.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef
Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b9678af60c95b0313931383334.html
# PDF berhasil diunduh: putusan/742_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b963d6a8768117313931383238.html
# PDF berhasil diunduh: putusan/741_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b962b6738692d4313931383236.html
# PDF berhasil diunduh: putusan/725_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b9602b3deaa859313931383232.html
# PDF berhasil diunduh: putusan/726_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b95eea6beaad85313931383230.html
# Tidak ada link PDF ditemukan di https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b95eea6beaad85313931383230.html
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b95c38c0048a12313931383136.html
# PDF berhasil diunduh: putusan/715_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b95ae58c78bebe313931383133.html
# PDF berhasil diunduh: putusan/713_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b959b11b10a28a313931383131.html
# PDF berhasil diunduh: putusan/716_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b958724044844b313931383039.html
# PDF berhasil diunduh: putusan/850_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa1b951ecf6b0977d313931373538.html
# PDF berhasil diunduh: putusan/839_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0eeded1efb6b664313930383437.html
# PDF berhasil diunduh: putusan/754_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0de285eb116b9a8313730393039.html
# PDF berhasil diunduh: putusan/815_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0de2710c51aa1d8313730393037.html
# PDF berhasil diunduh: putusan/816_Pid.Sus_2024_PN Rap.pdf
# Mengambil data dari: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0c5470080aea8cd313431313033.html
# PDF berhasil diunduh: putusan/749_Pid.Sus_2024_PN Rap.pdf
#
# Total halaman yang diproses: 51
# Berhasil diekstraksi: 51 (100.00%)
# Berhasil mengunduh PDF: 51 (100.00%)
# Gagal diekstraksi atau tidak sesuai: 0 (0.00%)
# Gagal mengunduh PDF: 0 (0.00%)
# Proses crawling selesai.

# %% [markdown]
# Pada bagian ini, kita mengakses halaman utama dan halaman selanjutnya untuk mengambil data putusan. Data putusan yang berhasil diambil disimpan dalam `putusan_list`. Setelah mencapai 50 data, proses pengambilan berhenti.

# %% [markdown]
# # Menyimpan Data ke CSV dan Mengemas PDF

# %%
# Membuat DataFrame untuk menyimpan data
df = pd.DataFrame(putusan_list)

# Menampilkan data
print(df)

# Menyimpan ke file CSV jika diperlukan
df.to_csv('data_putusan.csv', index=False)

# Menggunakan fungsi untuk membuat file ZIP
zip_path = 'putusan_files.zip'
create_zip_from_folder(pdf_folder, zip_path)
# Out:
#                       Nomor Lembaga Peradilan  \
# 0   932/Pid.Sus/2024/PN Rap                PN
# 1   943/Pid.Sus/2024/PN Rap                PN
# 2   946/Pid.Sus/2024/PN Rap                PN
# 3   837/Pid.Sus/2024/PN Rap                PN
# 4   953/Pid.Sus/2024/PN Rap                PN
# 5   951/Pid.Sus/2024/PN Rap                PN
# 6   870/Pid.Sus/2024/PN Rap                PN
# 7   917/Pid.Sus/2024/PN Rap                PN
# 8   871/Pid.Sus/2024/PN Rap                PN
# 9   854/Pid.Sus/2024/PN Rap                PN
# 10  874/Pid.Sus/2024/PN Rap                PN
# 11  855/Pid.Sus/2024/PN Rap                PN
# 12  817/Pid.Sus/2024/PN Rap                PN
# 13  835/Pid.Sus/2024/PN Rap                PN
# 14  834/Pid.Sus/2024/PN Rap                PN
# 15  942/Pid.Sus/2024/PN Rap                PN
# 16  841/Pid.Sus/2024/PN Rap                PN
# 17  830/Pid.Sus/2024/PN Rap                PN
# 18  842/Pid.Sus/2024/PN Rap                PN
# 19  944/Pid.Sus/2024/PN Rap                PN
# 20  820/Pid.Sus/2024/PN Rap                PN
# 21  814/Pid.Sus/2024/PN Rap                PN
# 22  890/Pid.Sus/2024/PN Rap                PN
# 23  873/Pid.Sus/2024/PN Rap                PN
# 24  801/Pid.Sus/2024/PN Rap                PN
# 25  831/Pid.Sus/2024/PN Rap                PN
# 26  810/Pid.Sus/2024/PN Rap                PN
# 27  916/Pid.Sus/2024/PN Rap                PN
# 28  799/Pid.Sus/2024/PN Rap                PN
# 29  730/Pid.Sus/2024/PN Rap                PN
# 30  731/Pid.Sus/2024/PN Rap                PN
# 31  729/Pid.Sus/2024/PN Rap                PN
# 32  849/Pid.Sus/2024/PN Rap                PN
# 33  748/Pid.Sus/2024/PN Rap                PN
# 34  861/Pid.Sus/2024/PN Rap                PN
# 35  845/Pid.Sus/2024/PN Rap                PN
# 36  811/Pid.Sus/2024/PN Rap                PN
# 37  840/Pid.Sus/2024/PN Rap                PN
# 38  742/Pid.Sus/2024/PN Rap                PN
# 39  741/Pid.Sus/2024/PN Rap                PN
# 40  725/Pid.Sus/2024/PN Rap                PN
# 41  726/Pid.Sus/2024/PN Rap                PN
# 42  715/Pid.Sus/2024/PN Rap                PN
# 43  713/Pid.Sus/2024/PN Rap                PN
# 44  716/Pid.Sus/2024/PN Rap                PN
# 45  850/Pid.Sus/2024/PN Rap                PN
# 46  839/Pid.Sus/2024/PN Rap                PN
# 47  754/Pid.Sus/2024/PN Rap                PN
# 48  815/Pid.Sus/2024/PN Rap                PN
# 49  816/Pid.Sus/2024/PN Rap                PN
# 50  749/Pid.Sus/2024/PN Rap                PN
#
#                                          Catatan Amar  \
# 0   MENGADILI:Menyatakan TerdakwaNur Afifah Adila ...
# 1   MENGADILI:Menyatakan Terdakwa Rindu Efendy Gul...
# 2   MENGADILIMenyatakan Terdakwa Joni Pransiscus S...
# 3   MENGADILI :Menyatakan Terdakwa Abdullah Hajar ...
# 4   MENGADILI:Menyatakan TerdakwaIndra Rosana Siah...
# 5   MENGADILI:Menyatakan TerdakwaFeri Silalahi ali...
# 6   MENGADILI:Menyatakan Terdakwa Heri Purnomo Ali...
# 7   MENGADILIMenyatakan Terdakwa Rio Saputra Munth...
# 8   MENGADILIMenyatakan Terdakwa M. Ardiansyah Ali...
# 9   MENGADILIMenyatakan Terdakwa I. Azmarizal Alia...
# 10  MENGADILI:Menyatakan Terdakwa M. Lokot Siregar...
# 11  MENGADILIMenyatakan Terdakwa Ceng Siang Alias ...
# 12  MENGADILI:Menyatakan TerdakwaErzy Septian alia...
# 13  MENGADILI:Menyatakan TerdakwaRudi Sucipto alia...
# 14  MENGADILI:Menyatakan TerdakwaSalimuddin Haraha...
# 15  MENGADILI:Menyatakan Terdakwa Darwin Sianturi ...
# 16  MENGADILI:Menyatakan Terdakwa I. Rahman Nasuti...
# 17  MENGADILI:Menyatakan Terdakwa Dodi Tata Ritong...
# 18  MENGADILIMenyatakan Terdakwa Gilang Rahmadan S...
# 12  1 (satu) plastik klip berisi narkotika jenis s...
# 13  1 (satu) buah plastik klip kecil berisi narkot...
# 14  2 (dua) plastik klip kecil yang berisikan nark...
# 15  7 (tujuh) bungkus kertas warna cokelat berisi ...
# 16  1 (satu) bungkus plastik klip kecil berisi nar...
# 17  2 (dua) bungkus plastik klip transparan berisi...
# 18  6 (enam) bungkus plastik klip kecil berisi Nar...
# 19  1 (satu) bungkus plastik klip berisi narkotika...
# 20  1 (satu) buah plastik klip berukuran sedang be...
# 21  3 (tiga) plastik klip berisi narkotika jenis s...
# 22       1 (satu) unit handphone merk Oppo warna biru
# 23  7 (tujuh) bungkus plastik klip transparan beri...
# 24  2 (dua) bungkus plastik klip bening yang beris...
# 25  4 (empat) bungkus plastik klip transparan beri...
# 26  1 (satu) bungkus plastik klip besar berisikan ...
# 27
# 28
# 29  5 (lima) bungkus plastik transparan berisi kri...
# 30  5 (lima) bungkus plastik transparan berisi kri...
# 31  1 (satu) bungkus plastik klip transparan beris...
# 32
# 33  1 (satu) bungkus plastik klip besar berisi Nar...
# 34  2 (dua) bungkus plastik klip transparan berisi...
# 35  1 (satu) bungkus plastik klip transparan beris...
# 36  1 (satu) bungkus plastik klip sedang berisi Na...
# 37  1 (satu) bungkus plastik klip besar transpara ...
# 38
# 39
# 40  1 (satu) unit handphone Android merek Oppo Ren...
# 41  2 (dua) bungkus plastik klip transparan sedang...
# 42  6 (enam) bungkus plastik klip berisikan sedang...
# 43  6 (enam) bungkus plastik klip berisikan sedang...
# 44  1 (satu) bungkus plastik klip sedang berisi na...
# 45  2 (dua) bungkus plastik klip sedang yang beris...
# 46  1 (satu) bungkus plastik klip trasnparan beris...
# 47  2 (dua) bungkus plastik klip kecil berisikan n...
# 48  1 (satu) buah bong (alat hisap sabu) terbuat d...
# 49  1 (satu) buah plastik klip berisi narkotika je...
# 50  4 (empat) bungkus plastik klip transparan beri...
# File ZIP berhasil dibuat: putusan_files.zip

# %% [markdown]
# Data yang berhasil diambil disimpan dalam DataFrame pandas dan kemudian disimpan ke file CSV. PDF yang diunduh juga dikemas dalam file ZIP.

# %% [markdown]
# # Mengekstrak PDF ke TXT

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
import os
import re
import zipfile
from PyPDF2 import PdfReader

# Fungsi untuk membersihkan dan merapikan teks yang diekstrak
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)  # Hilangkan whitespace yang tidak perlu
    text = re.sub(r'Direktori Putusan.*?putusan\.mahkamahagung\.go\.id', '', text, flags=re.IGNORECASE)  # Hilangkan watermark
    return text.strip()

# Fungsi untuk mengekstrak teks dari file PDF
def extract_pdf_to_txt(pdf_path, output_txt_path):
    try:
        reader = PdfReader(pdf_path)
        all_text = ""

        for page in reader.pages:
            raw_text = page.extract_text()
            cleaned_text = clean_text(raw_text)
            all_text += cleaned_text + "\n"

        with open(output_txt_path, 'w', encoding='utf-8') as txt_file:
            txt_file.write(all_text)

        print(f"Teks berhasil diekstrak ke: {output_txt_path}")
    except Exception as e:
        print(f"Terjadi kesalahan saat memproses file PDF: {e}")

# Fungsi untuk memproses semua file PDF dalam folder
def process_all_pdfs_in_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for file_name in os.listdir(input_folder):
        if file_name.lower().endswith('.pdf'):
            pdf_path = os.path.join(input_folder, file_name)
            output_txt_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.txt")
            extract_pdf_to_txt(pdf_path, output_txt_path)

# Fungsi untuk membuat zip dari folder output
def zip_output_folder(output_folder, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(output_folder):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, output_folder)
                zipf.write(file_path, arcname)
    print(f"Folder telah dikompres menjadi: {zip_path}")

# Fungsi untuk mengekstrak file ZIP
def extract_zip(input_zip_path, extract_to_folder):
    with zipfile.ZipFile(input_zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to_folder)
    print(f"File ZIP diekstrak ke: {extract_to_folder}")

# Contoh penggunaan
zip_input_path = "/content/putusan_files.zip"  # Path file ZIP
temp_extracted_folder = "/content/putusan_extracted"  # Folder sementara untuk file PDF
output_folder_path = "/content/txt_files"  # Folder output untuk file TXT
zip_output_path = "/content/txt_files.zip"  # Path untuk file ZIP hasil

# Ekstrak file ZIP
extract_zip(zip_input_path, temp_extracted_folder)

# Proses semua file PDF
process_all_pdfs_in_folder(temp_extracted_folder, output_folder_path)

# Kompres hasil TXT ke ZIP
zip_output_folder(output_folder_path, zip_output_path)
# Out:
# File ZIP diekstrak ke: /content/putusan_extracted
# Teks berhasil diekstrak ke: /content/txt_files/799_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/944_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/840_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/834_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/725_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/850_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/946_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/742_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/845_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/726_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/814_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/951_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/874_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/861_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/953_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/943_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/835_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/741_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/854_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/716_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/871_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/890_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/917_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/849_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/815_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/715_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/749_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/830_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/932_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/811_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/942_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/839_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/837_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/801_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/731_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/831_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/841_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/748_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/870_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/713_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/820_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/754_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/842_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/855_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/817_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/810_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/816_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/730_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/729_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/916_Pid.Sus_2024_PN Rap.txt
# Teks berhasil diekstrak ke: /content/txt_files/873_Pid.Sus_2024_PN Rap.txt
# Folder telah dikompres menjadi: /content/txt_files.zip

# %% [markdown]
# # Menambahkan tokens

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)

# %%
from transformers import pipeline

# %%
# Inisialisasi pipeline QA dengan model dan tokenizer Indobert
qa_pipeline = pipeline(
    "question-answering",
    model="Rifky/Indobert-QA",
    tokenizer="Rifky/Indobert-QA"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/532 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/234k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/480k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# Ekstrak tokenizer dari pipeline
tokenizer = qa_pipeline.tokenizer

# %%
# Fungsi untuk menghitung token menggunakan tokenizer baru
def count_tokens(text: str) -> int:
    return len(tokenizer.encode(text))

# %%
# Pastikan kolom tersebut ada dan proses penghitungan token
if 'Catatan Amar' in df.columns:
    # Isi nilai yang hilang
    df['Catatan Amar'] = df['Catatan Amar'].fillna('').astype(str)

    # Menerapkan fungsi count_tokens per baris
    df['Tokens'] = df['Catatan Amar'].apply(count_tokens)
else:
    print("Error: Column 'Catatan Amar' not found in DataFrame")

# %%
df
# Out:
#                       Nomor Lembaga Peradilan  \
# 0   932/Pid.Sus/2024/PN Rap                PN
# 1   943/Pid.Sus/2024/PN Rap                PN
# 2   946/Pid.Sus/2024/PN Rap                PN
# 3   837/Pid.Sus/2024/PN Rap                PN
# 4   953/Pid.Sus/2024/PN Rap                PN
# 5   951/Pid.Sus/2024/PN Rap                PN
# 6   870/Pid.Sus/2024/PN Rap                PN
# 7   917/Pid.Sus/2024/PN Rap                PN
# 8   871/Pid.Sus/2024/PN Rap                PN
# 9   854/Pid.Sus/2024/PN Rap                PN
# 10  874/Pid.Sus/2024/PN Rap                PN
# 11  855/Pid.Sus/2024/PN Rap                PN
# 12  817/Pid.Sus/2024/PN Rap                PN
# 13  835/Pid.Sus/2024/PN Rap                PN
# 14  834/Pid.Sus/2024/PN Rap                PN
# 15  942/Pid.Sus/2024/PN Rap                PN
# 16  841/Pid.Sus/2024/PN Rap                PN
# 17  830/Pid.Sus/2024/PN Rap                PN
# 18  842/Pid.Sus/2024/PN Rap                PN
# 19  944/Pid.Sus/2024/PN Rap                PN
# 20  820/Pid.Sus/2024/PN Rap                PN
# 21  814/Pid.Sus/2024/PN Rap                PN
# 22  890/Pid.Sus/2024/PN Rap                PN
# 23  873/Pid.Sus/2024/PN Rap                PN
# 24  801/Pid.Sus/2024/PN Rap                PN
# 25  831/Pid.Sus/2024/PN Rap                PN
# 26  810/Pid.Sus/2024/PN Rap                PN
# 27  916/Pid.Sus/2024/PN Rap                PN
# 28  799/Pid.Sus/2024/PN Rap                PN
# 29  730/Pid.Sus/2024/PN Rap                PN
# 30  731/Pid.Sus/2024/PN Rap                PN
# 31  729/Pid.Sus/2024/PN Rap                PN
# 32  849/Pid.Sus/2024/PN Rap                PN
# 33  748/Pid.Sus/2024/PN Rap                PN
# 34  861/Pid.Sus/2024/PN Rap                PN
# 35  845/Pid.Sus/2024/PN Rap                PN
# 36  811/Pid.Sus/2024/PN Rap                PN
# 37  840/Pid.Sus/2024/PN Rap                PN
# 38  742/Pid.Sus/2024/PN Rap                PN
# 39  741/Pid.Sus/2024/PN Rap                PN
# 40  725/Pid.Sus/2024/PN Rap                PN
# 41  726/Pid.Sus/2024/PN Rap                PN
# 42  715/Pid.Sus/2024/PN Rap                PN
# 43  713/Pid.Sus/2024/PN Rap                PN
# 44  716/Pid.Sus/2024/PN Rap                PN
# 45  850/Pid.Sus/2024/PN Rap                PN
# 46  839/Pid.Sus/2024/PN Rap                PN
# 47  754/Pid.Sus/2024/PN Rap                PN
# 48  815/Pid.Sus/2024/PN Rap                PN
# 49  816/Pid.Sus/2024/PN Rap                PN
# 50  749/Pid.Sus/2024/PN Rap                PN
#
#                                          Catatan Amar  \
# 0   MENGADILI:Menyatakan TerdakwaNur Afifah Adila ...
# 1   MENGADILI:Menyatakan Terdakwa Rindu Efendy Gul...
# 2   MENGADILIMenyatakan Terdakwa Joni Pransiscus S...
# 3   MENGADILI :Menyatakan Terdakwa Abdullah Hajar ...
# 4   MENGADILI:Menyatakan TerdakwaIndra Rosana Siah...
# 5   MENGADILI:Menyatakan TerdakwaFeri Silalahi ali...
# 48  putusan/815_Pid.Sus_2024_PN Rap.pdf
# 49  putusan/816_Pid.Sus_2024_PN Rap.pdf
# 50  putusan/749_Pid.Sus_2024_PN Rap.pdf
#
#                                          Barang Bukti  Tokens
# 0   1 (satu) bungkus plastik klip transparan sedan...     231
# 1   1 (satu) bungkus kertas warna cokelat berisi N...     188
# 2   2 (dua) buah plastik klip transparan berisi kr...     306
# 3   18 (delapan belas) bungkus kertas warna putih ...     251
# 4   1 (satu) bungkus plastik klip berisi kristal p...     287
# 5   1 (satu) bungkus plastik klip tembus pandang b...     279
# 6   1 (satu) bungkus plastik klip transparan beris...     343
# 7   2 (dua) bungkus plastik klip kecil transparan ...     294
# 8   1 (satu) bungkus plastik klip sedang berisi na...     223
# 9   1 (satu) bungkus plastik klip besar berisi Nar...     253
# 10  1 (satu) bungkus plastik klip transparan beris...     327
# 11  1 (satu) bungkus plastik klip kecil berisi nar...     412
# 12  1 (satu) plastik klip berisi narkotika jenis s...     216
# 13  1 (satu) buah plastik klip kecil berisi narkot...     211
# 14  2 (dua) plastik klip kecil yang berisikan nark...     277
# 15  7 (tujuh) bungkus kertas warna cokelat berisi ...     252
# 16  1 (satu) bungkus plastik klip kecil berisi nar...     321
# 17  2 (dua) bungkus plastik klip transparan berisi...     255
# 18  6 (enam) bungkus plastik klip kecil berisi Nar...     232
# 19  1 (satu) bungkus plastik klip berisi narkotika...     279
# 20  1 (satu) buah plastik klip berukuran sedang be...     252
# 21  3 (tiga) plastik klip berisi narkotika jenis s...     232
# 22       1 (satu) unit handphone merk Oppo warna biru     351
# 23  7 (tujuh) bungkus plastik klip transparan beri...     249
# 24  2 (dua) bungkus plastik klip bening yang beris...     200
# 25  4 (empat) bungkus plastik klip transparan beri...     226
# 26  1 (satu) bungkus plastik klip besar berisikan ...     274
# 27                                                        216
# 28                                                        289
# 29  5 (lima) bungkus plastik transparan berisi kri...     403
# 30  5 (lima) bungkus plastik transparan berisi kri...     232
# 31  1 (satu) bungkus plastik klip transparan beris...     361
# 32                                                        209
# 33  1 (satu) bungkus plastik klip besar berisi Nar...     359
# 34  2 (dua) bungkus plastik klip transparan berisi...     359
# 35  1 (satu) bungkus plastik klip transparan beris...     260
# 36  1 (satu) bungkus plastik klip sedang berisi Na...     245
# 37  1 (satu) bungkus plastik klip besar transpara ...     385
# 38                                                        308
# 39                                                        250
# 40  1 (satu) unit handphone Android merek Oppo Ren...     256
# 41  2 (dua) bungkus plastik klip transparan sedang...     215
# 42  6 (enam) bungkus plastik klip berisikan sedang...     279
# 43  6 (enam) bungkus plastik klip berisikan sedang...     275
# 44  1 (satu) bungkus plastik klip sedang berisi na...     346
# 45  2 (dua) bungkus plastik klip sedang yang beris...     394
# 46  1 (satu) bungkus plastik klip trasnparan beris...     224
# 47  2 (dua) bungkus plastik klip kecil berisikan n...     261
# 48  1 (satu) buah bong (alat hisap sabu) terbuat d...     370
# 49  1 (satu) buah plastik klip berisi narkotika je...     276
# 50  4 (empat) bungkus plastik klip transparan beri...     255

# %%
df_cleaned = df.dropna()

# %%
# Drop rows after the first 50
df = df_cleaned.iloc[:49]

# %%
df
# Out:
#                       Nomor Lembaga Peradilan  \
# 0   932/Pid.Sus/2024/PN Rap                PN
# 1   943/Pid.Sus/2024/PN Rap                PN
# 2   946/Pid.Sus/2024/PN Rap                PN
# 3   837/Pid.Sus/2024/PN Rap                PN
# 4   953/Pid.Sus/2024/PN Rap                PN
# 5   951/Pid.Sus/2024/PN Rap                PN
# 6   870/Pid.Sus/2024/PN Rap                PN
# 7   917/Pid.Sus/2024/PN Rap                PN
# 8   871/Pid.Sus/2024/PN Rap                PN
# 9   854/Pid.Sus/2024/PN Rap                PN
# 10  874/Pid.Sus/2024/PN Rap                PN
# 11  855/Pid.Sus/2024/PN Rap                PN
# 12  817/Pid.Sus/2024/PN Rap                PN
# 13  835/Pid.Sus/2024/PN Rap                PN
# 14  834/Pid.Sus/2024/PN Rap                PN
# 15  942/Pid.Sus/2024/PN Rap                PN
# 16  841/Pid.Sus/2024/PN Rap                PN
# 17  830/Pid.Sus/2024/PN Rap                PN
# 18  842/Pid.Sus/2024/PN Rap                PN
# 19  944/Pid.Sus/2024/PN Rap                PN
# 20  820/Pid.Sus/2024/PN Rap                PN
# 21  814/Pid.Sus/2024/PN Rap                PN
# 22  890/Pid.Sus/2024/PN Rap                PN
# 23  873/Pid.Sus/2024/PN Rap                PN
# 24  801/Pid.Sus/2024/PN Rap                PN
# 25  831/Pid.Sus/2024/PN Rap                PN
# 26  810/Pid.Sus/2024/PN Rap                PN
# 27  916/Pid.Sus/2024/PN Rap                PN
# 28  799/Pid.Sus/2024/PN Rap                PN
# 29  730/Pid.Sus/2024/PN Rap                PN
# 30  731/Pid.Sus/2024/PN Rap                PN
# 31  729/Pid.Sus/2024/PN Rap                PN
# 32  849/Pid.Sus/2024/PN Rap                PN
# 33  748/Pid.Sus/2024/PN Rap                PN
# 34  861/Pid.Sus/2024/PN Rap                PN
# 35  845/Pid.Sus/2024/PN Rap                PN
# 36  811/Pid.Sus/2024/PN Rap                PN
# 37  840/Pid.Sus/2024/PN Rap                PN
# 38  742/Pid.Sus/2024/PN Rap                PN
# 39  741/Pid.Sus/2024/PN Rap                PN
# 40  725/Pid.Sus/2024/PN Rap                PN
# 41  726/Pid.Sus/2024/PN Rap                PN
# 42  715/Pid.Sus/2024/PN Rap                PN
# 43  713/Pid.Sus/2024/PN Rap                PN
# 44  716/Pid.Sus/2024/PN Rap                PN
# 45  850/Pid.Sus/2024/PN Rap                PN
# 46  839/Pid.Sus/2024/PN Rap                PN
# 47  754/Pid.Sus/2024/PN Rap                PN
# 48  815/Pid.Sus/2024/PN Rap                PN
#
#                                          Catatan Amar  \
# 0   MENGADILI:Menyatakan TerdakwaNur Afifah Adila ...
# 1   MENGADILI:Menyatakan Terdakwa Rindu Efendy Gul...
# 2   MENGADILIMenyatakan Terdakwa Joni Pransiscus S...
# 3   MENGADILI :Menyatakan Terdakwa Abdullah Hajar ...
# 47  putusan/754_Pid.Sus_2024_PN Rap.pdf
# 48  putusan/815_Pid.Sus_2024_PN Rap.pdf
#
#                                          Barang Bukti  Tokens
# 0   1 (satu) bungkus plastik klip transparan sedan...     231
# 1   1 (satu) bungkus kertas warna cokelat berisi N...     188
# 2   2 (dua) buah plastik klip transparan berisi kr...     306
# 3   18 (delapan belas) bungkus kertas warna putih ...     251
# 4   1 (satu) bungkus plastik klip berisi kristal p...     287
# 5   1 (satu) bungkus plastik klip tembus pandang b...     279
# 6   1 (satu) bungkus plastik klip transparan beris...     343
# 7   2 (dua) bungkus plastik klip kecil transparan ...     294
# 8   1 (satu) bungkus plastik klip sedang berisi na...     223
# 9   1 (satu) bungkus plastik klip besar berisi Nar...     253
# 10  1 (satu) bungkus plastik klip transparan beris...     327
# 11  1 (satu) bungkus plastik klip kecil berisi nar...     412
# 12  1 (satu) plastik klip berisi narkotika jenis s...     216
# 13  1 (satu) buah plastik klip kecil berisi narkot...     211
# 14  2 (dua) plastik klip kecil yang berisikan nark...     277
# 15  7 (tujuh) bungkus kertas warna cokelat berisi ...     252
# 16  1 (satu) bungkus plastik klip kecil berisi nar...     321
# 17  2 (dua) bungkus plastik klip transparan berisi...     255
# 18  6 (enam) bungkus plastik klip kecil berisi Nar...     232
# 19  1 (satu) bungkus plastik klip berisi narkotika...     279
# 20  1 (satu) buah plastik klip berukuran sedang be...     252
# 21  3 (tiga) plastik klip berisi narkotika jenis s...     232
# 22       1 (satu) unit handphone merk Oppo warna biru     351
# 23  7 (tujuh) bungkus plastik klip transparan beri...     249
# 24  2 (dua) bungkus plastik klip bening yang beris...     200
# 25  4 (empat) bungkus plastik klip transparan beri...     226
# 26  1 (satu) bungkus plastik klip besar berisikan ...     274
# 27                                                        216
# 28                                                        289
# 29  5 (lima) bungkus plastik transparan berisi kri...     403
# 30  5 (lima) bungkus plastik transparan berisi kri...     232
# 31  1 (satu) bungkus plastik klip transparan beris...     361
# 32                                                        209
# 33  1 (satu) bungkus plastik klip besar berisi Nar...     359
# 34  2 (dua) bungkus plastik klip transparan berisi...     359
# 35  1 (satu) bungkus plastik klip transparan beris...     260
# 36  1 (satu) bungkus plastik klip sedang berisi Na...     245
# 37  1 (satu) bungkus plastik klip besar transpara ...     385
# 38                                                        308
# 39                                                        250
# 40  1 (satu) unit handphone Android merek Oppo Ren...     256
# 41  2 (dua) bungkus plastik klip transparan sedang...     215
# 42  6 (enam) bungkus plastik klip berisikan sedang...     279
# 43  6 (enam) bungkus plastik klip berisikan sedang...     275
# 44  1 (satu) bungkus plastik klip sedang berisi na...     346
# 45  2 (dua) bungkus plastik klip sedang yang beris...     394
# 46  1 (satu) bungkus plastik klip trasnparan beris...     224
# 47  2 (dua) bungkus plastik klip kecil berisikan n...     261
# 48  1 (satu) buah bong (alat hisap sabu) terbuat d...     370

# %%
# Menyimpan atau meninjau DataFrame yang telah diperbarui
df.to_csv('datasets.csv', index=False)
print("Token counts have been added and saved to 'datasets.csv'.")
# Out:
# Token counts have been added and saved to 'datasets.csv'.
